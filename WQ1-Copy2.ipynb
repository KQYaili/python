# %% [markdown]
# <br><br>

# %% [markdown]
# # 下面这行代码里的邮箱和密码，要改为自己的邮箱和密码

# %% [markdown]
# <br><br>

# %%
import requests
import json
from os.path import expanduser
from requests.auth import HTTPBasicAuth

# 创建会话对象
sess = requests.Session()

# 设置基本身份验证
sess.auth = HTTPBasicAuth('邮箱', '密码')

# 向API发送POST请求进行身份验证
response = sess.post('https://api.worldquantbrain.com/authentication')

# 打印响应状态和内容以调试
print(response.status_code)
print(response.json())

# %%
simulation_data = {
    'type': 'REGULAR',
    'settings': {
        'instrumentType': 'EQUITY',
        'region': 'USA',
        'universe': 'TOP3000',
        'delay': 1,
        'decay': 0,
        'neutralization': 'SUBINDUSTRY',
        'truncation': 0.08,
        'pasteurization': 'ON',
        'unitHandling': 'VERIFY',
        'nanHandling': 'OFF',
        'language': 'FASTEXPR',
        'visualization': False,
    },
    'regular': 'liabilities/assets'  ## 写表达式
}

from time import sleep

sim_resp = sess.post(
    'https://api.worldquantbrain.com/simulations',
    json=simulation_data,
)

sim_progress_url = sim_resp.headers['Location']

while True:
    sim_progress_resp = sess.get(sim_progress_url)
    retry_after_sec = float(sim_progress_resp.headers.get("Retry-After", 0))
    if retry_after_sec == 0:  # simulation done!模拟完成!
        break
    sleep(retry_after_sec)

alpha_id = sim_progress_resp.json()["alpha"]  # the final simulation result 模拟最终模拟结果

print(alpha_id)
# Out:
# 2lVOkw6

# %%
# 获取数据集ID为fundamental6（Company Fundamental Data for Equity）下的所有数据字段
### Get Data_fields like Data Explorer 获取所有满足条件的数据字段及其ID
def get_datafields(
        s,
        searchScope,
        dataset_id: str = '',
        search: str = ''
):
    import pandas as pd
    instrument_type = searchScope['instrumentType']
    region = searchScope['region']
    delay = searchScope['delay']
    universe = searchScope['universe']

    if len(search) == 0:
        url_template = "https://api.worldquantbrain.com/data-fields?" + \
                       f"&instrumentType={instrument_type}" + \
                       f"&region={region}&delay={str(delay)}&universe={universe}&dataset.id={dataset_id}&limit=50" + \
                       "&offset={x}"
        count = s.get(url_template.format(x=0)).json()['count']
    else:
        url_template = "https://api.worldquantbrain.com/data-fields?" + \
                       f"&instrumentType={instrument_type}" + \
                       f"&region={region}&delay={str(delay)}&universe={universe}&limit=50" + \
                       f"&search={search}" + \
                       "&offset={x}"
        count = 100

    datafields_list = []
    for x in range(0, count, 50):
        datafields = s.get(url_template.format(x=x))
        datafields_list.append(datafields.json()['results'])

    datafields_list_flat = [item for sublist in datafields_list for item in sublist]

    datafields_df = pd.DataFrame(datafields_list_flat)
    return datafields_df

# 爬取id
searchScope = {'region': 'USA', 'delay': '1', 'universe': 'TOP3000', 'instrumentType': 'EQUITY'}
fundamental6 = get_datafields(s=sess, searchScope=searchScope, dataset_id='analyst4') # id设置

# 筛选（这里是type的MATRIX）
fundamental6 = fundamental6[fundamental6['type'] == "MATRIX"]
fundamental6.head()

datafields_list_fundamental6 = fundamental6['id'].values
print(datafields_list_fundamental6[:5])
print(len(datafields_list_fundamental6))
# Out:
# ['anl4_adjusted_netincome_ft' 'anl4_bvps_flag' 'anl4_bvps_high'
#  'anl4_bvps_low' 'anl4_bvps_mean']
# 202

# %%
# 将datafield替换到Alpha模板(框架)中group_rank({fundamental model data}/cap,subindustry)批量生成Alpha
alpha_list = []

for index,datafield in enumerate(datafields_list_fundamental6,start=1):
    print(f"正在循环第 {index} 个元素")
    print("正在将如下alpha表达式与setting封装")
    #alpha_expression = f'group_rank(({datafield})/cap, subindustry)'
    alpha_expression = f'trade_when(close>ts_mean(close,90),{datafield},-1)'
    print(alpha_expression)
    simulation_data = {
        "type": "REGULAR",
        "settings": {
            "instrumentType": "EQUITY",
            "region": "USA",
            "universe": "TOP3000",
            "delay": 1,
            "decay": 0,
            "neutralization": "SUBINDUSTRY",
            "truncation": 0.02,
            "pasteurization": "ON",
            "unitHandling": "VERIFY",
            "nanHandling": "ON",
            "language": "FASTEXPR",
            "visualization": False,
        },
        "regular": alpha_expression
    }
    alpha_list.append(simulation_data)
    print(f"there are {len(alpha_list)} Alphas to simulate")

    
for index,datafield in enumerate(datafields_list_fundamental6,start=1):
    print(f"正在循环第 {index} 个元素")
    print("正在将如下alpha表达式与setting封装")
    #alpha_expression = f'group_rank(({datafield})/cap, subindustry)'
    alpha_expression = f'trade_when(close>ts_mean(close,90),ts_rank({datafield},90),-1)'
    #trade_when(close>ts_mean(close,300),-scl12_buzz,-1) 
    print(alpha_expression)
    simulation_data = {
        "type": "REGULAR",
        "settings": {
            "instrumentType": "EQUITY",
            "region": "USA",
            "universe": "TOP3000",
            "delay": 1,
            "decay": 0,
            "neutralization": "SUBINDUSTRY",
            "truncation": 0.02,
            "pasteurization": "ON",
            "unitHandling": "VERIFY",
            "nanHandling": "ON",
            "language": "FASTEXPR",
            "visualization": False,
        },
        "regular": alpha_expression
    }
    alpha_list.append(simulation_data)
    print(f"there are {len(alpha_list)} Alphas to simulate")

print(alpha_list[1])
# Out:
# 正在循环第 1 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_adjusted_netincome_ft,-1)
# there are 1 Alphas to simulate
# 正在循环第 2 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_bvps_flag,-1)
# there are 2 Alphas to simulate
# 正在循环第 3 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_bvps_high,-1)
# there are 3 Alphas to simulate
# 正在循环第 4 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_bvps_low,-1)
# there are 4 Alphas to simulate
# 正在循环第 5 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_bvps_mean,-1)
# there are 5 Alphas to simulate
# 正在循环第 6 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_bvps_median,-1)
# there are 6 Alphas to simulate
# 正在循环第 7 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_bvps_number,-1)
# there are 7 Alphas to simulate
# 正在循环第 8 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_bvps_value,-1)
# there are 8 Alphas to simulate
# 正在循环第 9 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_capex_flag,-1)
# there are 9 Alphas to simulate
# 正在循环第 10 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_capex_high,-1)
# there are 10 Alphas to simulate
# 正在循环第 11 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_capex_low,-1)
# there are 11 Alphas to simulate
# 正在循环第 12 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_capex_mean,-1)
# there are 12 Alphas to simulate
# 正在循环第 13 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_capex_number,-1)
# there are 13 Alphas to simulate
# 正在循环第 14 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_capex_std,-1)
# there are 14 Alphas to simulate
# 正在循环第 15 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_capex_value,-1)
# there are 15 Alphas to simulate
# 正在循环第 16 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_cff_flag,-1)
# there are 16 Alphas to simulate
# 正在循环第 17 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_cff_high,-1)
# there are 17 Alphas to simulate
# 正在循环第 18 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_cff_low,-1)
# there are 18 Alphas to simulate
# 正在循环第 19 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_cff_mean,-1)
# there are 19 Alphas to simulate
# 正在循环第 20 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_cff_median,-1)
# there are 20 Alphas to simulate
# 正在循环第 21 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_cff_number,-1)
# there are 21 Alphas to simulate
# 正在循环第 22 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_cff_value,-1)
# there are 22 Alphas to simulate
# 正在循环第 23 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_cfi_flag,-1)
# there are 23 Alphas to simulate
# 正在循环第 24 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_cfi_high,-1)
# there are 24 Alphas to simulate
# 正在循环第 25 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_cfi_low,-1)
# there are 25 Alphas to simulate
# 正在循环第 26 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_cfi_mean,-1)
# there are 26 Alphas to simulate
# 正在循环第 27 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_cfi_median,-1)
# there are 27 Alphas to simulate
# 正在循环第 28 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_cfi_number,-1)
# there are 28 Alphas to simulate
# 正在循环第 29 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_cfi_value,-1)
# there are 29 Alphas to simulate
# 正在循环第 30 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_cfo_flag,-1)
# there are 30 Alphas to simulate
# 正在循环第 31 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_cfo_high,-1)
# there are 31 Alphas to simulate
# 正在循环第 32 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_cfo_low,-1)
# there are 32 Alphas to simulate
# 正在循环第 33 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_cfo_mean,-1)
# there are 33 Alphas to simulate
# 正在循环第 34 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_cfo_median,-1)
# there are 34 Alphas to simulate
# 正在循环第 35 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_cfo_number,-1)
# there are 35 Alphas to simulate
# 正在循环第 36 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_cfo_value,-1)
# there are 36 Alphas to simulate
# 正在循环第 37 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_dts_ptp,-1)
# there are 37 Alphas to simulate
# 正在循环第 38 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_dts_rspe,-1)
# there are 38 Alphas to simulate
# 正在循环第 39 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ebit_high,-1)
# there are 39 Alphas to simulate
# 正在循环第 40 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ebit_low,-1)
# there are 40 Alphas to simulate
# 正在循环第 41 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ebit_mean,-1)
# there are 41 Alphas to simulate
# 正在循环第 42 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ebit_median,-1)
# there are 42 Alphas to simulate
# 正在循环第 43 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ebit_number,-1)
# there are 43 Alphas to simulate
# 正在循环第 44 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ebit_std,-1)
# there are 44 Alphas to simulate
# 正在循环第 45 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ebit_value,-1)
# there are 45 Alphas to simulate
# 正在循环第 46 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ebitda_flag,-1)
# there are 46 Alphas to simulate
# 正在循环第 47 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ebitda_high,-1)
# there are 47 Alphas to simulate
# 正在循环第 48 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ebitda_low,-1)
# there are 48 Alphas to simulate
# 正在循环第 49 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ebitda_mean,-1)
# there are 49 Alphas to simulate
# 正在循环第 50 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ebitda_number,-1)
# there are 50 Alphas to simulate
# 正在循环第 51 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ebitda_std,-1)
# there are 51 Alphas to simulate
# 正在循环第 52 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ebitda_value,-1)
# there are 52 Alphas to simulate
# 正在循环第 53 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_epsa_flag,-1)
# there are 53 Alphas to simulate
# 正在循环第 54 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_epsr_flag,-1)
# there are 54 Alphas to simulate
# 正在循环第 55 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_epsr_high,-1)
# there are 55 Alphas to simulate
# 正在循环第 56 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_epsr_low,-1)
# there are 56 Alphas to simulate
# 正在循环第 57 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_epsr_mean,-1)
# there are 57 Alphas to simulate
# 正在循环第 58 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_epsr_number,-1)
# there are 58 Alphas to simulate
# 正在循环第 59 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_epsr_value,-1)
# there are 59 Alphas to simulate
# 正在循环第 60 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_fcf_flag,-1)
# there are 60 Alphas to simulate
# 正在循环第 61 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_fcf_high,-1)
# there are 61 Alphas to simulate
# 正在循环第 62 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_fcf_low,-1)
# there are 62 Alphas to simulate
# 正在循环第 63 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_fcf_mean,-1)
# there are 63 Alphas to simulate
# 正在循环第 64 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_fcf_median,-1)
# there are 64 Alphas to simulate
# 正在循环第 65 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_fcf_number,-1)
# there are 65 Alphas to simulate
# 正在循环第 66 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_fcf_value,-1)
# there are 66 Alphas to simulate
# 正在循环第 67 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_fcfps_flag,-1)
# there are 67 Alphas to simulate
# 正在循环第 68 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_fcfps_high,-1)
# there are 68 Alphas to simulate
# 正在循环第 69 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_fcfps_low,-1)
# there are 69 Alphas to simulate
# 正在循环第 70 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_fcfps_mean,-1)
# there are 70 Alphas to simulate
# 正在循环第 71 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_fcfps_median,-1)
# there are 71 Alphas to simulate
# 正在循环第 72 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_fcfps_number,-1)
# there are 72 Alphas to simulate
# 正在循环第 73 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ffo_flag,-1)
# there are 73 Alphas to simulate
# 正在循环第 74 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_flag_erbfintax,-1)
# there are 74 Alphas to simulate
# 正在循环第 75 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_gric_flag,-1)
# there are 75 Alphas to simulate
# 正在循环第 76 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_gric_high,-1)
# there are 76 Alphas to simulate
# 正在循环第 77 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_gric_low,-1)
# there are 77 Alphas to simulate
# 正在循环第 78 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_gric_mean,-1)
# there are 78 Alphas to simulate
# 正在循环第 79 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_gric_median,-1)
# there are 79 Alphas to simulate
# 正在循环第 80 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_gric_number,-1)
# there are 80 Alphas to simulate
# 正在循环第 81 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_gric_std,-1)
# there are 81 Alphas to simulate
# 正在循环第 82 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_gric_value,-1)
# there are 82 Alphas to simulate
# 正在循环第 83 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_median_capexp,-1)
# there are 83 Alphas to simulate
# 正在循环第 84 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_median_epsreported,-1)
# there are 84 Alphas to simulate
# 正在循环第 85 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_medianepsbfam,-1)
# there are 85 Alphas to simulate
# 正在循环第 86 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_netdebt_flag,-1)
# there are 86 Alphas to simulate
# 正在循环第 87 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_netdebt_high,-1)
# there are 87 Alphas to simulate
# 正在循环第 88 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_netdebt_low,-1)
# there are 88 Alphas to simulate
# 正在循环第 89 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_netdebt_mean,-1)
# there are 89 Alphas to simulate
# 正在循环第 90 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_netdebt_median,-1)
# there are 90 Alphas to simulate
# 正在循环第 91 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_netdebt_number,-1)
# there are 91 Alphas to simulate
# 正在循环第 92 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_netprofit_flag,-1)
# there are 92 Alphas to simulate
# 正在循环第 93 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_netprofit_high,-1)
# there are 93 Alphas to simulate
# 正在循环第 94 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_netprofit_low,-1)
# there are 94 Alphas to simulate
# 正在循环第 95 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_netprofit_mean,-1)
# there are 95 Alphas to simulate
# 正在循环第 96 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_netprofit_median,-1)
# there are 96 Alphas to simulate
# 正在循环第 97 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_netprofit_number,-1)
# there are 97 Alphas to simulate
# 正在循环第 98 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_netprofit_std,-1)
# there are 98 Alphas to simulate
# 正在循环第 99 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_netprofit_value,-1)
# there are 99 Alphas to simulate
# 正在循环第 100 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_netprofita_high,-1)
# there are 100 Alphas to simulate
# 正在循环第 101 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_netprofita_low,-1)
# there are 101 Alphas to simulate
# 正在循环第 102 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_netprofita_mean,-1)
# there are 102 Alphas to simulate
# 正在循环第 103 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_netprofita_median,-1)
# there are 103 Alphas to simulate
# 正在循环第 104 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_netprofita_number,-1)
# there are 104 Alphas to simulate
# 正在循环第 105 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_netprofita_std,-1)
# there are 105 Alphas to simulate
# 正在循环第 106 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_netprofita_value,-1)
# there are 106 Alphas to simulate
# 正在循环第 107 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ptp_flag,-1)
# there are 107 Alphas to simulate
# 正在循环第 108 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ptp_high,-1)
# there are 108 Alphas to simulate
# 正在循环第 109 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ptp_low,-1)
# there are 109 Alphas to simulate
# 正在循环第 110 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ptp_mean,-1)
# there are 110 Alphas to simulate
# 正在循环第 111 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ptp_median,-1)
# there are 111 Alphas to simulate
# 正在循环第 112 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ptp_number,-1)
# there are 112 Alphas to simulate
# 正在循环第 113 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ptp_value,-1)
# there are 113 Alphas to simulate
# 正在循环第 114 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ptpr_flag,-1)
# there are 114 Alphas to simulate
# 正在循环第 115 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ptpr_high,-1)
# there are 115 Alphas to simulate
# 正在循环第 116 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ptpr_low,-1)
# there are 116 Alphas to simulate
# 正在循环第 117 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ptpr_mean,-1)
# there are 117 Alphas to simulate
# 正在循环第 118 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ptpr_median,-1)
# there are 118 Alphas to simulate
# 正在循环第 119 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_ptpr_number,-1)
# there are 119 Alphas to simulate
# 正在循环第 120 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qf_az_cfps_mean,-1)
# there are 120 Alphas to simulate
# 正在循环第 121 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qf_az_cfps_median,-1)
# there are 121 Alphas to simulate
# 正在循环第 122 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qf_az_cfps_number,-1)
# there are 122 Alphas to simulate
# 正在循环第 123 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qf_az_div_mean,-1)
# there are 123 Alphas to simulate
# 正在循环第 124 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qf_az_div_median,-1)
# there are 124 Alphas to simulate
# 正在循环第 125 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qf_az_div_number,-1)
# there are 125 Alphas to simulate
# 正在循环第 126 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qf_az_dts_spe,-1)
# there are 126 Alphas to simulate
# 正在循环第 127 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qf_az_eps,-1)
# there are 127 Alphas to simulate
# 正在循环第 128 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qf_az_eps_mean,-1)
# there are 128 Alphas to simulate
# 正在循环第 129 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qf_az_eps_number,-1)
# there are 129 Alphas to simulate
# 正在循环第 130 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qf_az_hgih_spe,-1)
# there are 130 Alphas to simulate
# 正在循环第 131 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qf_az_hgih_spfc,-1)
# there are 131 Alphas to simulate
# 正在循环第 132 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qf_az_hgih_vid,-1)
# there are 132 Alphas to simulate
# 正在循环第 133 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qf_az_wol_spe,-1)
# there are 133 Alphas to simulate
# 正在循环第 134 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qf_az_wol_spfc,-1)
# there are 134 Alphas to simulate
# 正在循环第 135 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qf_az_wol_vid,-1)
# there are 135 Alphas to simulate
# 正在循环第 136 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qfd1_az_cfps_median,-1)
# there are 136 Alphas to simulate
# 正在循环第 137 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qfd1_az_cfps_number,-1)
# there are 137 Alphas to simulate
# 正在循环第 138 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qfd1_az_div_median,-1)
# there are 138 Alphas to simulate
# 正在循环第 139 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qfd1_az_div_number,-1)
# there are 139 Alphas to simulate
# 正在循环第 140 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qfd1_az_dts_spe,-1)
# there are 140 Alphas to simulate
# 正在循环第 141 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qfd1_az_eps_number,-1)
# there are 141 Alphas to simulate
# 正在循环第 142 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qfd1_az_hgih_spe,-1)
# there are 142 Alphas to simulate
# 正在循环第 143 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qfd1_az_hgih_spfc,-1)
# there are 143 Alphas to simulate
# 正在循环第 144 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qfd1_az_hgih_vid,-1)
# there are 144 Alphas to simulate
# 正在循环第 145 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qfd1_az_wol_spe,-1)
# there are 145 Alphas to simulate
# 正在循环第 146 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qfd1_az_wol_spfc,-1)
# there are 146 Alphas to simulate
# 正在循环第 147 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qfd1_az_wol_vid,-1)
# there are 147 Alphas to simulate
# 正在循环第 148 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_qfd1_azeps,-1)
# there are 148 Alphas to simulate
# 正在循环第 149 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_rd_exp_flag,-1)
# there are 149 Alphas to simulate
# 正在循环第 150 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_rd_exp_high,-1)
# there are 150 Alphas to simulate
# 正在循环第 151 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_rd_exp_low,-1)
# there are 151 Alphas to simulate
# 正在循环第 152 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_rd_exp_mean,-1)
# there are 152 Alphas to simulate
# 正在循环第 153 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_rd_exp_median,-1)
# there are 153 Alphas to simulate
# 正在循环第 154 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_rd_exp_number,-1)
# there are 154 Alphas to simulate
# 正在循环第 155 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_tbve_ft,-1)
# there are 155 Alphas to simulate
# 正在循环第 156 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_tbvps_high,-1)
# there are 156 Alphas to simulate
# 正在循环第 157 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_tbvps_low,-1)
# there are 157 Alphas to simulate
# 正在循环第 158 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_tbvps_mean,-1)
# there are 158 Alphas to simulate
# 正在循环第 159 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_tbvps_median,-1)
# there are 159 Alphas to simulate
# 正在循环第 160 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_tbvps_number,-1)
# there are 160 Alphas to simulate
# 正在循环第 161 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_tot_gw_ft,-1)
# there are 161 Alphas to simulate
# 正在循环第 162 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_totassets_flag,-1)
# there are 162 Alphas to simulate
# 正在循环第 163 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_totassets_high,-1)
# there are 163 Alphas to simulate
# 正在循环第 164 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_totassets_low,-1)
# there are 164 Alphas to simulate
# 正在循环第 165 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_totassets_mean,-1)
# there are 165 Alphas to simulate
# 正在循环第 166 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_totassets_median,-1)
# there are 166 Alphas to simulate
# 正在循环第 167 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_totassets_number,-1)
# there are 167 Alphas to simulate
# 正在循环第 168 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_totassets_std,-1)
# there are 168 Alphas to simulate
# 正在循环第 169 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_totassets_value,-1)
# there are 169 Alphas to simulate
# 正在循环第 170 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_totgw_high,-1)
# there are 170 Alphas to simulate
# 正在循环第 171 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_totgw_low,-1)
# there are 171 Alphas to simulate
# 正在循环第 172 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_totgw_mean,-1)
# there are 172 Alphas to simulate
# 正在循环第 173 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_totgw_median,-1)
# there are 173 Alphas to simulate
# 正在循环第 174 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),anl4_totgw_number,-1)
# there are 174 Alphas to simulate
# 正在循环第 175 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_bookvalue_ps,-1)
# there are 175 Alphas to simulate
# 正在循环第 176 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_capex,-1)
# there are 176 Alphas to simulate
# 正在循环第 177 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_cashflow_fin,-1)
# there are 177 Alphas to simulate
# 正在循环第 178 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_cashflow_invst,-1)
# there are 178 Alphas to simulate
# 正在循环第 179 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_cashflow_op,-1)
# there are 179 Alphas to simulate
# 正在循环第 180 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_cashflow_ps,-1)
# there are 180 Alphas to simulate
# 正在循环第 181 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_dividend_ps,-1)
# there are 181 Alphas to simulate
# 正在循环第 182 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_ebit,-1)
# there are 182 Alphas to simulate
# 正在循环第 183 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_ebitda,-1)
# there are 183 Alphas to simulate
# 正在循环第 184 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_eps,-1)
# there are 184 Alphas to simulate
# 正在循环第 185 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_epsa,-1)
# there are 185 Alphas to simulate
# 正在循环第 186 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_epsr,-1)
# there are 186 Alphas to simulate
# 正在循环第 187 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_fcf,-1)
# there are 187 Alphas to simulate
# 正在循环第 188 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_fcf_ps,-1)
# there are 188 Alphas to simulate
# 正在循环第 189 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_ffo,-1)
# there are 189 Alphas to simulate
# 正在循环第 190 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_grossincome,-1)
# there are 190 Alphas to simulate
# 正在循环第 191 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_netdebt,-1)
# there are 191 Alphas to simulate
# 正在循环第 192 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_netprofit,-1)
# there are 192 Alphas to simulate
# 正在循环第 193 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_netprofit_adj,-1)
# there are 193 Alphas to simulate
# 正在循环第 194 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_ptp,-1)
# there are 194 Alphas to simulate
# 正在循环第 195 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_ptpr,-1)
# there are 195 Alphas to simulate
# 正在循环第 196 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_rd_expense,-1)
# there are 196 Alphas to simulate
# 正在循环第 197 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_sales,-1)
# there are 197 Alphas to simulate
# 正在循环第 198 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_sga,-1)
# there are 198 Alphas to simulate
# 正在循环第 199 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_shequity,-1)
# there are 199 Alphas to simulate
# 正在循环第 200 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_tbv_ps,-1)
# there are 200 Alphas to simulate
# 正在循环第 201 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_tot_assets,-1)
# there are 201 Alphas to simulate
# 正在循环第 202 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),est_tot_goodwill,-1)
# there are 202 Alphas to simulate
# 正在循环第 1 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_adjusted_netincome_ft,90),-1)
# there are 203 Alphas to simulate
# 正在循环第 2 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_bvps_flag,90),-1)
# there are 204 Alphas to simulate
# 正在循环第 3 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_bvps_high,90),-1)
# there are 205 Alphas to simulate
# 正在循环第 4 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_bvps_low,90),-1)
# there are 206 Alphas to simulate
# 正在循环第 5 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_bvps_mean,90),-1)
# there are 207 Alphas to simulate
# 正在循环第 6 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_bvps_median,90),-1)
# there are 208 Alphas to simulate
# 正在循环第 7 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_bvps_number,90),-1)
# there are 209 Alphas to simulate
# 正在循环第 8 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_bvps_value,90),-1)
# there are 210 Alphas to simulate
# 正在循环第 9 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_capex_flag,90),-1)
# there are 211 Alphas to simulate
# 正在循环第 10 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_capex_high,90),-1)
# there are 212 Alphas to simulate
# 正在循环第 11 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_capex_low,90),-1)
# there are 213 Alphas to simulate
# 正在循环第 12 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_capex_mean,90),-1)
# there are 214 Alphas to simulate
# 正在循环第 13 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_capex_number,90),-1)
# there are 215 Alphas to simulate
# 正在循环第 14 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_capex_std,90),-1)
# there are 216 Alphas to simulate
# 正在循环第 15 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_capex_value,90),-1)
# there are 217 Alphas to simulate
# 正在循环第 16 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_cff_flag,90),-1)
# there are 218 Alphas to simulate
# 正在循环第 17 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_cff_high,90),-1)
# there are 219 Alphas to simulate
# 正在循环第 18 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_cff_low,90),-1)
# there are 220 Alphas to simulate
# 正在循环第 19 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_cff_mean,90),-1)
# there are 221 Alphas to simulate
# 正在循环第 20 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_cff_median,90),-1)
# there are 222 Alphas to simulate
# 正在循环第 21 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_cff_number,90),-1)
# there are 223 Alphas to simulate
# 正在循环第 22 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_cff_value,90),-1)
# there are 224 Alphas to simulate
# 正在循环第 23 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_cfi_flag,90),-1)
# there are 225 Alphas to simulate
# 正在循环第 24 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_cfi_high,90),-1)
# there are 226 Alphas to simulate
# 正在循环第 25 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_cfi_low,90),-1)
# there are 227 Alphas to simulate
# 正在循环第 26 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_cfi_mean,90),-1)
# there are 228 Alphas to simulate
# 正在循环第 27 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_cfi_median,90),-1)
# there are 229 Alphas to simulate
# 正在循环第 28 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_cfi_number,90),-1)
# there are 230 Alphas to simulate
# 正在循环第 29 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_cfi_value,90),-1)
# there are 231 Alphas to simulate
# 正在循环第 30 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_cfo_flag,90),-1)
# there are 232 Alphas to simulate
# 正在循环第 31 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_cfo_high,90),-1)
# there are 233 Alphas to simulate
# 正在循环第 32 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_cfo_low,90),-1)
# there are 234 Alphas to simulate
# 正在循环第 33 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_cfo_mean,90),-1)
# there are 235 Alphas to simulate
# 正在循环第 34 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_cfo_median,90),-1)
# there are 236 Alphas to simulate
# 正在循环第 35 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_cfo_number,90),-1)
# there are 237 Alphas to simulate
# 正在循环第 36 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_cfo_value,90),-1)
# there are 238 Alphas to simulate
# 正在循环第 37 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_dts_ptp,90),-1)
# there are 239 Alphas to simulate
# 正在循环第 38 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_dts_rspe,90),-1)
# there are 240 Alphas to simulate
# 正在循环第 39 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ebit_high,90),-1)
# there are 241 Alphas to simulate
# 正在循环第 40 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ebit_low,90),-1)
# there are 242 Alphas to simulate
# 正在循环第 41 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ebit_mean,90),-1)
# there are 243 Alphas to simulate
# 正在循环第 42 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ebit_median,90),-1)
# there are 244 Alphas to simulate
# 正在循环第 43 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ebit_number,90),-1)
# there are 245 Alphas to simulate
# 正在循环第 44 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ebit_std,90),-1)
# there are 246 Alphas to simulate
# 正在循环第 45 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ebit_value,90),-1)
# there are 247 Alphas to simulate
# 正在循环第 46 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ebitda_flag,90),-1)
# there are 248 Alphas to simulate
# 正在循环第 47 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ebitda_high,90),-1)
# there are 249 Alphas to simulate
# 正在循环第 48 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ebitda_low,90),-1)
# there are 250 Alphas to simulate
# 正在循环第 49 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ebitda_mean,90),-1)
# there are 251 Alphas to simulate
# 正在循环第 50 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ebitda_number,90),-1)
# there are 252 Alphas to simulate
# 正在循环第 51 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ebitda_std,90),-1)
# there are 253 Alphas to simulate
# 正在循环第 52 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ebitda_value,90),-1)
# there are 254 Alphas to simulate
# 正在循环第 53 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_epsa_flag,90),-1)
# there are 255 Alphas to simulate
# 正在循环第 54 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_epsr_flag,90),-1)
# there are 256 Alphas to simulate
# 正在循环第 55 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_epsr_high,90),-1)
# there are 257 Alphas to simulate
# 正在循环第 56 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_epsr_low,90),-1)
# there are 258 Alphas to simulate
# 正在循环第 57 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_epsr_mean,90),-1)
# there are 259 Alphas to simulate
# 正在循环第 58 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_epsr_number,90),-1)
# there are 260 Alphas to simulate
# 正在循环第 59 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_epsr_value,90),-1)
# there are 261 Alphas to simulate
# 正在循环第 60 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_fcf_flag,90),-1)
# there are 262 Alphas to simulate
# 正在循环第 61 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_fcf_high,90),-1)
# there are 263 Alphas to simulate
# 正在循环第 62 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_fcf_low,90),-1)
# there are 264 Alphas to simulate
# 正在循环第 63 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_fcf_mean,90),-1)
# there are 265 Alphas to simulate
# 正在循环第 64 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_fcf_median,90),-1)
# there are 266 Alphas to simulate
# 正在循环第 65 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_fcf_number,90),-1)
# there are 267 Alphas to simulate
# 正在循环第 66 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_fcf_value,90),-1)
# there are 268 Alphas to simulate
# 正在循环第 67 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_fcfps_flag,90),-1)
# there are 269 Alphas to simulate
# 正在循环第 68 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_fcfps_high,90),-1)
# there are 270 Alphas to simulate
# 正在循环第 69 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_fcfps_low,90),-1)
# there are 271 Alphas to simulate
# 正在循环第 70 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_fcfps_mean,90),-1)
# there are 272 Alphas to simulate
# 正在循环第 71 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_fcfps_median,90),-1)
# there are 273 Alphas to simulate
# 正在循环第 72 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_fcfps_number,90),-1)
# there are 274 Alphas to simulate
# 正在循环第 73 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ffo_flag,90),-1)
# there are 275 Alphas to simulate
# 正在循环第 74 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_flag_erbfintax,90),-1)
# there are 276 Alphas to simulate
# 正在循环第 75 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_gric_flag,90),-1)
# there are 277 Alphas to simulate
# 正在循环第 76 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_gric_high,90),-1)
# there are 278 Alphas to simulate
# 正在循环第 77 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_gric_low,90),-1)
# there are 279 Alphas to simulate
# 正在循环第 78 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_gric_mean,90),-1)
# there are 280 Alphas to simulate
# 正在循环第 79 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_gric_median,90),-1)
# there are 281 Alphas to simulate
# 正在循环第 80 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_gric_number,90),-1)
# there are 282 Alphas to simulate
# 正在循环第 81 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_gric_std,90),-1)
# there are 283 Alphas to simulate
# 正在循环第 82 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_gric_value,90),-1)
# there are 284 Alphas to simulate
# 正在循环第 83 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_median_capexp,90),-1)
# there are 285 Alphas to simulate
# 正在循环第 84 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_median_epsreported,90),-1)
# there are 286 Alphas to simulate
# 正在循环第 85 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_medianepsbfam,90),-1)
# there are 287 Alphas to simulate
# 正在循环第 86 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_netdebt_flag,90),-1)
# there are 288 Alphas to simulate
# 正在循环第 87 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_netdebt_high,90),-1)
# there are 289 Alphas to simulate
# 正在循环第 88 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_netdebt_low,90),-1)
# there are 290 Alphas to simulate
# 正在循环第 89 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_netdebt_mean,90),-1)
# there are 291 Alphas to simulate
# 正在循环第 90 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_netdebt_median,90),-1)
# there are 292 Alphas to simulate
# 正在循环第 91 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_netdebt_number,90),-1)
# there are 293 Alphas to simulate
# 正在循环第 92 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_netprofit_flag,90),-1)
# there are 294 Alphas to simulate
# 正在循环第 93 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_netprofit_high,90),-1)
# there are 295 Alphas to simulate
# 正在循环第 94 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_netprofit_low,90),-1)
# there are 296 Alphas to simulate
# 正在循环第 95 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_netprofit_mean,90),-1)
# there are 297 Alphas to simulate
# 正在循环第 96 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_netprofit_median,90),-1)
# there are 298 Alphas to simulate
# 正在循环第 97 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_netprofit_number,90),-1)
# there are 299 Alphas to simulate
# 正在循环第 98 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_netprofit_std,90),-1)
# there are 300 Alphas to simulate
# 正在循环第 99 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_netprofit_value,90),-1)
# there are 301 Alphas to simulate
# 正在循环第 100 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_netprofita_high,90),-1)
# there are 302 Alphas to simulate
# 正在循环第 101 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_netprofita_low,90),-1)
# there are 303 Alphas to simulate
# 正在循环第 102 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_netprofita_mean,90),-1)
# there are 304 Alphas to simulate
# 正在循环第 103 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_netprofita_median,90),-1)
# there are 305 Alphas to simulate
# 正在循环第 104 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_netprofita_number,90),-1)
# there are 306 Alphas to simulate
# 正在循环第 105 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_netprofita_std,90),-1)
# there are 307 Alphas to simulate
# 正在循环第 106 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_netprofita_value,90),-1)
# there are 308 Alphas to simulate
# 正在循环第 107 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ptp_flag,90),-1)
# there are 309 Alphas to simulate
# 正在循环第 108 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ptp_high,90),-1)
# there are 310 Alphas to simulate
# 正在循环第 109 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ptp_low,90),-1)
# there are 311 Alphas to simulate
# 正在循环第 110 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ptp_mean,90),-1)
# there are 312 Alphas to simulate
# 正在循环第 111 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ptp_median,90),-1)
# there are 313 Alphas to simulate
# 正在循环第 112 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ptp_number,90),-1)
# there are 314 Alphas to simulate
# 正在循环第 113 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ptp_value,90),-1)
# there are 315 Alphas to simulate
# 正在循环第 114 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ptpr_flag,90),-1)
# there are 316 Alphas to simulate
# 正在循环第 115 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ptpr_high,90),-1)
# there are 317 Alphas to simulate
# 正在循环第 116 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ptpr_low,90),-1)
# there are 318 Alphas to simulate
# 正在循环第 117 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ptpr_mean,90),-1)
# there are 319 Alphas to simulate
# 正在循环第 118 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ptpr_median,90),-1)
# there are 320 Alphas to simulate
# 正在循环第 119 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_ptpr_number,90),-1)
# there are 321 Alphas to simulate
# 正在循环第 120 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qf_az_cfps_mean,90),-1)
# there are 322 Alphas to simulate
# 正在循环第 121 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qf_az_cfps_median,90),-1)
# there are 323 Alphas to simulate
# 正在循环第 122 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qf_az_cfps_number,90),-1)
# there are 324 Alphas to simulate
# 正在循环第 123 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qf_az_div_mean,90),-1)
# there are 325 Alphas to simulate
# 正在循环第 124 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qf_az_div_median,90),-1)
# there are 326 Alphas to simulate
# 正在循环第 125 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qf_az_div_number,90),-1)
# there are 327 Alphas to simulate
# 正在循环第 126 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qf_az_dts_spe,90),-1)
# there are 328 Alphas to simulate
# 正在循环第 127 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qf_az_eps,90),-1)
# there are 329 Alphas to simulate
# 正在循环第 128 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qf_az_eps_mean,90),-1)
# there are 330 Alphas to simulate
# 正在循环第 129 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qf_az_eps_number,90),-1)
# there are 331 Alphas to simulate
# 正在循环第 130 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qf_az_hgih_spe,90),-1)
# there are 332 Alphas to simulate
# 正在循环第 131 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qf_az_hgih_spfc,90),-1)
# there are 333 Alphas to simulate
# 正在循环第 132 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qf_az_hgih_vid,90),-1)
# there are 334 Alphas to simulate
# 正在循环第 133 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qf_az_wol_spe,90),-1)
# there are 335 Alphas to simulate
# 正在循环第 134 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qf_az_wol_spfc,90),-1)
# there are 336 Alphas to simulate
# 正在循环第 135 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qf_az_wol_vid,90),-1)
# there are 337 Alphas to simulate
# 正在循环第 136 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qfd1_az_cfps_median,90),-1)
# there are 338 Alphas to simulate
# 正在循环第 137 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qfd1_az_cfps_number,90),-1)
# there are 339 Alphas to simulate
# 正在循环第 138 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qfd1_az_div_median,90),-1)
# there are 340 Alphas to simulate
# 正在循环第 139 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qfd1_az_div_number,90),-1)
# there are 341 Alphas to simulate
# 正在循环第 140 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qfd1_az_dts_spe,90),-1)
# there are 342 Alphas to simulate
# 正在循环第 141 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qfd1_az_eps_number,90),-1)
# there are 343 Alphas to simulate
# 正在循环第 142 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qfd1_az_hgih_spe,90),-1)
# there are 344 Alphas to simulate
# 正在循环第 143 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qfd1_az_hgih_spfc,90),-1)
# there are 345 Alphas to simulate
# 正在循环第 144 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qfd1_az_hgih_vid,90),-1)
# there are 346 Alphas to simulate
# 正在循环第 145 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qfd1_az_wol_spe,90),-1)
# there are 347 Alphas to simulate
# 正在循环第 146 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qfd1_az_wol_spfc,90),-1)
# there are 348 Alphas to simulate
# 正在循环第 147 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qfd1_az_wol_vid,90),-1)
# there are 349 Alphas to simulate
# 正在循环第 148 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_qfd1_azeps,90),-1)
# there are 350 Alphas to simulate
# 正在循环第 149 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_rd_exp_flag,90),-1)
# there are 351 Alphas to simulate
# 正在循环第 150 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_rd_exp_high,90),-1)
# there are 352 Alphas to simulate
# 正在循环第 151 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_rd_exp_low,90),-1)
# there are 353 Alphas to simulate
# 正在循环第 152 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_rd_exp_mean,90),-1)
# there are 354 Alphas to simulate
# 正在循环第 153 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_rd_exp_median,90),-1)
# there are 355 Alphas to simulate
# 正在循环第 154 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_rd_exp_number,90),-1)
# there are 356 Alphas to simulate
# 正在循环第 155 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_tbve_ft,90),-1)
# there are 357 Alphas to simulate
# 正在循环第 156 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_tbvps_high,90),-1)
# there are 358 Alphas to simulate
# 正在循环第 157 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_tbvps_low,90),-1)
# there are 359 Alphas to simulate
# 正在循环第 158 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_tbvps_mean,90),-1)
# there are 360 Alphas to simulate
# 正在循环第 159 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_tbvps_median,90),-1)
# there are 361 Alphas to simulate
# 正在循环第 160 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_tbvps_number,90),-1)
# there are 362 Alphas to simulate
# 正在循环第 161 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_tot_gw_ft,90),-1)
# there are 363 Alphas to simulate
# 正在循环第 162 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_totassets_flag,90),-1)
# there are 364 Alphas to simulate
# 正在循环第 163 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_totassets_high,90),-1)
# there are 365 Alphas to simulate
# 正在循环第 164 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_totassets_low,90),-1)
# there are 366 Alphas to simulate
# 正在循环第 165 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_totassets_mean,90),-1)
# there are 367 Alphas to simulate
# 正在循环第 166 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_totassets_median,90),-1)
# there are 368 Alphas to simulate
# 正在循环第 167 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_totassets_number,90),-1)
# there are 369 Alphas to simulate
# 正在循环第 168 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_totassets_std,90),-1)
# there are 370 Alphas to simulate
# 正在循环第 169 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_totassets_value,90),-1)
# there are 371 Alphas to simulate
# 正在循环第 170 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_totgw_high,90),-1)
# there are 372 Alphas to simulate
# 正在循环第 171 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_totgw_low,90),-1)
# there are 373 Alphas to simulate
# 正在循环第 172 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_totgw_mean,90),-1)
# there are 374 Alphas to simulate
# 正在循环第 173 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_totgw_median,90),-1)
# there are 375 Alphas to simulate
# 正在循环第 174 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(anl4_totgw_number,90),-1)
# there are 376 Alphas to simulate
# 正在循环第 175 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_bookvalue_ps,90),-1)
# there are 377 Alphas to simulate
# 正在循环第 176 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_capex,90),-1)
# there are 378 Alphas to simulate
# 正在循环第 177 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_cashflow_fin,90),-1)
# there are 379 Alphas to simulate
# 正在循环第 178 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_cashflow_invst,90),-1)
# there are 380 Alphas to simulate
# 正在循环第 179 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_cashflow_op,90),-1)
# there are 381 Alphas to simulate
# 正在循环第 180 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_cashflow_ps,90),-1)
# there are 382 Alphas to simulate
# 正在循环第 181 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_dividend_ps,90),-1)
# there are 383 Alphas to simulate
# 正在循环第 182 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_ebit,90),-1)
# there are 384 Alphas to simulate
# 正在循环第 183 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_ebitda,90),-1)
# there are 385 Alphas to simulate
# 正在循环第 184 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_eps,90),-1)
# there are 386 Alphas to simulate
# 正在循环第 185 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_epsa,90),-1)
# there are 387 Alphas to simulate
# 正在循环第 186 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_epsr,90),-1)
# there are 388 Alphas to simulate
# 正在循环第 187 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_fcf,90),-1)
# there are 389 Alphas to simulate
# 正在循环第 188 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_fcf_ps,90),-1)
# there are 390 Alphas to simulate
# 正在循环第 189 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_ffo,90),-1)
# there are 391 Alphas to simulate
# 正在循环第 190 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_grossincome,90),-1)
# there are 392 Alphas to simulate
# 正在循环第 191 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_netdebt,90),-1)
# there are 393 Alphas to simulate
# 正在循环第 192 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_netprofit,90),-1)
# there are 394 Alphas to simulate
# 正在循环第 193 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_netprofit_adj,90),-1)
# there are 395 Alphas to simulate
# 正在循环第 194 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_ptp,90),-1)
# there are 396 Alphas to simulate
# 正在循环第 195 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_ptpr,90),-1)
# there are 397 Alphas to simulate
# 正在循环第 196 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_rd_expense,90),-1)
# there are 398 Alphas to simulate
# 正在循环第 197 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_sales,90),-1)
# there are 399 Alphas to simulate
# 正在循环第 198 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_sga,90),-1)
# there are 400 Alphas to simulate
# 正在循环第 199 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_shequity,90),-1)
# there are 401 Alphas to simulate
# 正在循环第 200 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_tbv_ps,90),-1)
# there are 402 Alphas to simulate
# 正在循环第 201 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_tot_assets,90),-1)
# there are 403 Alphas to simulate
# 正在循环第 202 个元素
# 正在将如下alpha表达式与setting封装
# trade_when(close>ts_mean(close,90),ts_rank(est_tot_goodwill,90),-1)
# there are 404 Alphas to simulate
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'USA', 'universe': 'TOP3000', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.02, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'ON', 'language': 'FASTEXPR', 'visualization': False}, 'regular': 'trade_when(close>ts_mean(close,90),anl4_bvps_flag,-1)'}

# %%
print(alpha_list[1])
# Out:
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'USA', 'universe': 'TOP3000', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.02, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'ON', 'language': 'FASTEXPR', 'visualization': False}, 'regular': 'trade_when(close>ts_mean(close,90),anl4_bvps_flag,-1)'}

# %%
##################测试前两个##############################
from time import sleep

for index,alpha in enumerate(alpha_list[0:2],start=1):
    sim_resp = sess.post(
        'https://api.worldquantbrain.com/simulations',
        json=alpha,
    )

    try:
        sim_progress_url = sim_resp.headers['Location']
        while True:
            sim_progress_resp = sess.get(sim_progress_url)
            retry_after_sec = float(sim_progress_resp.headers.get("Retry-After", 0))
            if retry_after_sec == 0:  # simulation done!模拟完成!
                break
            sleep(retry_after_sec)
        alpha_id = sim_progress_resp.json()["alpha"]  # the final simulation result.# 最终模拟结果
        print(alpha_id)
    except:
        print("no location, sleep for 10 seconds and try next alpha.“没有位置，睡10秒然后尝试下一个字母。”")
        sleep(10)

#################################################
# Out:
# r53WvQo
# 39bALZz

# %%
# 将Alpha一个一个发送至服务器进行回测（已经测试前两个了）
from time import sleep

for index,alpha in enumerate(alpha_list,start=1):
    sim_resp = sess.post(
        'https://api.worldquantbrain.com/simulations',
        json=alpha,
    )

    try:
        sim_progress_url = sim_resp.headers['Location']
        while True:
            sim_progress_resp = sess.get(sim_progress_url)
            retry_after_sec = float(sim_progress_resp.headers.get("Retry-After", 0))
            if retry_after_sec == 0:  # simulation done!模拟完成!
                break
            sleep(retry_after_sec)
        alpha_id = sim_progress_resp.json()["alpha"]  # the final simulation result.# 最终模拟结果
        print(alpha_id)
    except:
        print("no location, sleep for 10 seconds and try next alpha.“没有位置，睡10秒然后尝试下一个字母。”")
        sleep(10)
# Out:
# r53WvQo
# 39bALZz
# bRk9pRr
# dOXQeEX
# zYMWwao
# xY6n9vn
# 0Rl8Qb2
# mg3XzNK
# RV3rd2d
# 39bAAzQ
# e9prOmE
# xY6nxJq
# 5QbvOX1
# 9VvR73o
# pPX7jAj
# M1Wx1x9
# mg3X6Rx
# gQA3ZLQ
# 9VvRExd
# 39bAoK0
# Ev7KmZJ
# GdaoQRx
# Ev7K8Xr
# 39bAPEZ
# dOXQo0K
# nKJWrLw
# Gdao72o
# Q3JQpGM
# o6pYj9l
# Gdao28J
# dOXQGLX
# 9VvRnkr
# 9VvRNRd
# RV3pJW1
# OrYp0xd
# NQwpxqo
# 39b7w1P
# dOXxVM2
# Ev7wJ5m
# nKJgb2x
# wYmR6El
# OrYpKog
# A0WwJ8Y
# aLYdlLv
# 9Vvw6OK
# KO0bXJl
# 7ZAwd3L
